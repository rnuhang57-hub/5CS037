# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8de259c9-3ce6-486b-ba96-296187dc3c54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8de259c9-3ce6-486b-ba96-296187dc3c54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Saving bank.csv to bank (1).csv

# %% [markdown]
# 1. Load the provided dataset and import

# %%
import pandas as pd
df = pd.read_csv("bank.csv")
df.head()

# %% [markdown]
# 2(a) Columns with dtype = object

# %%
object_Col = df.select_dtypes(include="object").columns
print(object_Col)

# %% [markdown]
# 2(b) Unique values of those object columns

# %%
for col in object_Col:
    print(f"Unique values: '{col}':")
    print()
    print(df[col].unique())

# %% [markdown]
# 2(c) Total number of null values in each column

# %%
df.isnull().sum()

# %% [markdown]
#  3) Drop all the columns with dtypes object and store in new DataFrame, also write the DataFrame in
#  ”.csv” with name ”banknumericdata.csv”

# %%
numeric_df = df.select_dtypes(exclude="object")

numeric_df.to_csv("banknumericdata.csv", index=False)

numeric_df.head()

# %% [markdown]
# 4.. Load numeric CSV & summary statistics

# %%
bank_numeric_data = pd.read_csv("banknumericdata.csv")
bank_numeric_data.describe()

# %% [markdown]
# Problem 2 — Medical Student Dataset
# • Dataset for the Task: "medical_student.csv"

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# 1. Load the provided dataset and import in pandas DataFrame.

# %%
medi = pd.read_csv("medical_students_dataset.csv")
medi.head()

# %% [markdown]
# 2. Check info of the DataFrame and identify column with missing (null) values.

# %%
medi.isnull().sum()

# %% [markdown]
# 3. For the column with missing values fill the values using various techniques we discussed above. Try
# to explain why did you select the particular methods for particular column.

# %% [markdown]
# For numeric balance mean is one of the particular methods to measure the average of data set.

# %%
num_cols = medi.select_dtypes(include='number').columns
medi[num_cols] = medi[num_cols].fillna(medi[num_cols].mean())

# %% [markdown]
# Categorical values are measured through mode so, the column of number can be calculated through mode.

# %%
num_cols = medi.select_dtypes(include='number').columns
medi[num_cols] = medi[num_cols].fillna(medi[num_cols].median())

# %% [markdown]
# 4. Check for any duplicate values present in Dataset and do necessary to manage the duplicate items.
# {Hint: dataset.duplicated.sum()}

# %%
medi.duplicated().sum()

# %% [markdown]
# 3.2 Exercises - Data Cleaning and Transformations with ”Titanic Dataset”:
# Dataset Used: "titanic.csv"
# Problem - 1:

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Saving Titanic-Dataset.csv to Titanic-Dataset.csv

# %% [markdown]
# Load Dataset

# %%
titanic = pd.read_csv("Titanic-Dataset.csv")
titanic.head()

# %%
df1 = titanic[['Name','Pclass','Sex','Age','Fare','Survived']]
df1 = df1[df1['Pclass'] == 1]

df1['Fare'].describe()

# %% [markdown]
# Problem - 2:
# How many null values are contained in the ’Age’ column in your subsetted DataFrame? Once you’ve found
# this out, drop them from your DataFrame.

# %%
df1['Age'].isnull().sum()

df1 = df1.dropna(subset=['Age'])

# %% [markdown]
# Problem - 3:
#
# The ’Embarked’ column in the Titanic dataset contains categorical data representing the ports of embarka-
# tion:
#
# • ’C’ for Cherbourg
# • ’Q’ for Queenstown
# • ’S’ for Southampton

# %%
 #creates dummy columns from Embarked

embarked_dummies = pd.get_dummies(titanic['Embarked'], prefix="Embarked")

#creates new data frame and adds them
titanic = pd.concat([titanic, embarked_dummies], axis=1)

titanic.drop("Embarked", axis=1, inplace=True)

titanic.head()

# %% [markdown]
# Problem - 4:
#
# Compare the mean survival rates (’Survived’) for the different groups in the ’Sex’ column. Draw a visual-
# ization to show how the survival distributions vary by gender.

# %%
titanic.groupby("Sex")["Survived"].mean()

# %% [markdown]
# visualization

# %%
titanic.groupby("Sex")["Survived"].mean().plot(kind='bar')

plt.title("Survival Rate of male / female")
plt.ylabel("Probability of survival")
plt.show()

# %% [markdown]
# Problem - 5:
#
# Draw a visualization that breaks your visualization from Exercise 3 down by the port of embarkation (’Em-
# barked’). In this instance, compare the ports ’C’ (Cherbourg), ’Q’ (Queenstown), and ’S’ (Southampton).

# %%
titanic.groupby("Embarked_Q")["Survived"].mean()
titanic.groupby("Embarked_S")["Survived"].mean()
titanic.groupby("Embarked_C")["Survived"].mean()

# %%
survival = [
    titanic.groupby("Embarked_C")["Survived"].mean()[1],
    titanic.groupby("Embarked_Q")["Survived"].mean()[1],
    titanic.groupby("Embarked_S")["Survived"].mean()[1]
]

ports = ["Cherbourg", "Queenstown", "Southampton"]

plt.bar(ports, survival)
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Embarkation Port")
plt.show()
